# %%
with open('smartprix.html','r',encoding='utf-8') as f:
    html = f.read()

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
soup = BeautifulSoup(html,'lxml')

# %%
containers = soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}):
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        prices.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)
        
    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
len(names)
# Out:
# 1020

# %%
len(prices)
# Out:
# 1020

# %%
len(ratings)
# Out:
# 1020

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings
})

# %%
df.isnull().sum()
# Out:
# model       0
# price       0
# rating    266
# dtype: int64

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df
# Out:
#                                           model      price rating  \
# 0                      Samsung Galaxy S25 Ultra  ₹1,07,309    NaN
# 1                         Samsung Galaxy S25 FE    ₹51,085     77
# 2                       Motorola Edge 70 Fusion    ₹26,999     70
# 3                        Nothing Phone (4a) Pro    ₹39,999     74
# 4                                   Ai+ Pulse 2     ₹5,999    NaN
# ...                                         ...        ...    ...
# 1015     Xiaomi Redmi Note 12 (8GB RAM + 256GB)    ₹17,795     61
# 1016                                  Realme 11    ₹18,999     58
# 1017               Vivo Y100A (8GB RAM + 256GB)    ₹22,197     58
# 1018                                 Vivo Y100A    ₹17,998     57
# 1019  Xiaomi Redmi Note 12 4G (6GB RAM + 128GB)    ₹14,999     55
#
#                                                  sim  \
# 0      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 2      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 3            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 4                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# ...                                              ...
# 1015  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 1016              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1018              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1019      Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
#
#                                               processor  \
# 0     Snapdragon 8 Elite for Galaxy, Octa Core, 4.47...
# 1             Exynos 2400, Deca Core, 3.2 GHz Processor
# 2      Snapdragon 7s Gen4, Octa Core, 2.7 GHz Processor
# 3      Snapdragon 7 Gen 4, Octa Core, 2.8 GHz Processor
# 4            Unisoc T7250, Octa Core, 1.8 GHz Processor
# ...                                                 ...
# 1015     Snapdragon 4 Gen 1, Octa Core, 2 GHz Processor
# 1016  Dimensity 6100 Plus, Octa Core, 2.2 GHz Processor
# 1017       Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1018       Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019       Snapdragon 685, Octa Core, 2.8 GHz Processor
#
#                             ram                                  battery  \
# 0     12 GB RAM, 256 GB inbuilt  5000 mAh Battery with 45W Fast Charging
# 1      8 GB RAM, 128 GB inbuilt  4900 mAh Battery with 45W Fast Charging
# 2      8 GB RAM, 128 GB inbuilt  7000 mAh Battery with 68W Fast Charging
# 3      8 GB RAM, 128 GB inbuilt  5400 mAh Battery with 50W Fast Charging
# 4       4 GB RAM, 64 GB inbuilt  6000 mAh Battery with 10W Fast Charging
# ...                         ...                                      ...
# 1015   8 GB RAM, 256 GB inbuilt  5000 mAh Battery with 33W Fast Charging
# 1016   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 67W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt  4500 mAh Battery with 44W Fast Charging
# 1018   8 GB RAM, 128 GB inbuilt  4500 mAh Battery with 44W Fast Charging
# 1019   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 33W Fast Charging
#
#                                                 display  \
# 0     6.9 inches, 1440 x 3120 px, 120 Hz Display wit...
# 1     6.7 inches, 1080 x 2340 px, 120 Hz Display wit...
# 2     6.8 inches, 1272 x 2772 px, 144 Hz Display wit...
# 3     6.83 inches, 1260 x 2800 px, 144 Hz Display wi...
# 4     6.75 inches, 720 x 1600 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 1016  6.72 inches, 1080 x 2400 px, 120 Hz Display wi...
# 1017  6.38 inches, 1080 x 2400 px, 90 Hz Display wit...
# 1018  6.38 inches, 1080 x 2400 px, 90 Hz Display wit...
# 1019  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
#
#                                                  camera  \
# 0                 200 MP Quad Rear & 12 MP Front Camera
# 1     50 MP + 12 MP + 8 MP Triple Rear & 12 MP Front...
# 2     50 MP + 13 MP + Dedicated 3-in-1 light sensor ...
# 3     50 MP + 50 MP + 8 MP Triple Rear & 32 MP Front...
# 4                        50 MP Rear & 8 MP Front Camera
# ...                                                 ...
# 1015  48 MP + 8 MP + 2 MP Triple Rear & 13 MP Front ...
# 1016       108 MP + 2 MP Dual Rear & 16 MP Front Camera
# 1017  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 1019  50 MP + 8 MP + 2 MP Triple Rear & 13 MP Front ...
#
#                                   card           os
# 0            Memory Card Not Supported  Android v15
# 1            Memory Card Not Supported  Android v16
# 2                          Android v16  No FM Radio
# 3            Memory Card Not Supported  Android v16
# 4     Memory Card Supported, upto 1 TB  Android v16
# ...                                ...          ...
# 1015   Memory Card (Hybrid), upto 1 TB  Android v12
# 1016  Memory Card Supported, upto 1 TB  Android v13
# 1017              Memory Card (Hybrid)  Android v13
# 1018              Memory Card (Hybrid)  Android v13
# 1019   Memory Card (Hybrid), upto 1 TB  Android v13
#
# [1020 rows x 11 columns]

# %%
df.to_csv('smartprix_phones_data.csv', index=False)
print("Data saved to smartprix_phones_data.csv")
# Out:
# Data saved to smartprix_phones_data.csv
